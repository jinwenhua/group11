# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.model_selection import cross_val_score 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score
from sklearn import metrics
from sklearn import preprocessing
from sklearn.decomposition import PCA 
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import RFE

# %%
df = pd.read_csv('winequality-white.csv', delimiter = ';')
df.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
#
#    alcohol  quality
# 0      8.8        6

# %%
cut_bins = [1, 4, 6, 9]
df['quality'] = pd.cut(df['quality'], bins = cut_bins, labels = [0, 1, 2])
df['quality'].value_counts()
# Out:
# 1    3655
# 2    1060
# 0     183
# Name: quality, dtype: int64

# %%
df.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
#
#    alcohol quality
# 0      8.8       1

# %%
# Indicate the target column
target = df['quality']

# Indicate the columns that will serve as features
features = df.drop('quality', axis = 1)

features.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  alcohol
# 0                 45.0                 170.0    1.001  3.0       0.45      8.8

# %%
# Split the dataset into training and test sets
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

# %%
# Train and Evaluate model performance
def performance(estimators, x_train, x_test, y_train, y_test):

    def print_validation_performance(estimator, x_train, y_train, name = None, cv = 5):
        
        print(estimator.__class__)
        
        scores = cross_val_score(estimator, x_train, y_train, cv = cv, scoring = 'accuracy')

        print("Accuracy (validation){}".format(scores.mean()))
    
    def print_test_performance(estimator, x_train, x_test, y_train, y_test, name = None):
        
        estimator.fit(x_train, y_train)
        
        test_predict = estimator.predict(x_test)
        
        print("Accuracy (test):{}".format(metrics.accuracy_score(y_test, test_predict)))
               
        print(confusion_matrix(y_test, test_predict))
        
        print(classification_report(y_test, test_predict))            
    
    # Print validation and test performance for all classifiers in the list.
    for estimator in estimators:
        
        print_validation_performance(estimators[estimator], x_train, y_train, name = estimator)
        
        print_test_performance(estimators[estimator], x_train, x_test, y_train, y_test, name = estimator)
        
        print()

# %%
# Define 3 different estimators
estimators = {
    
    "KNN": KNeighborsClassifier(n_neighbors = 11, p = 1, weights = 'distance'),
    "Decision Tree": DecisionTreeClassifier(criterion = 'entropy', max_depth=7),
    "SVM": SVC(C = 1, gamma = 'auto', kernel = 'rbf')
}

# %%
#Scaling Data
def normalize_scaler(df):
    
    names = x_train.columns
    
    # Create the Scaler object   
    scaler = preprocessing.Normalizer()
    
    # Fit the data on the Scaler object    
    scaled_features = scaler.fit_transform(x_train)
    
    # After normalization, scaled_features is transformed into an array so we need to convert it
    scaled_features_df = pd.DataFrame(scaled_features, columns = names)
    
    return scaled_features_df

# %%
# Filter approach using Variance Threshold

# Compute the variance of each column
normalize_scaler(df).var().sort_values(ascending=False)
# Out:
# free sulfur dioxide     6.900638e-03
# alcohol                 1.569927e-03
# residual sugar          1.240375e-03
# total sulfur dioxide    6.201797e-04
# fixed acidity           5.774087e-04
# pH                      1.049855e-04
# density                 1.025616e-05
# sulphates               2.764116e-06
# citric acid             1.900910e-06
# volatile acidity        1.787987e-06
# chlorides               3.916266e-08
# dtype: float64

# %%
#Case 1: All features
performance(estimators, x_train, x_test, y_train, y_test)
# Out:
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.8014279849870984
# Accuracy (test):0.8030612244897959
# [[  3  26   1]
#  [  2 667  54]
#  [  0 110 117]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.10      0.17        30
#            1       0.83      0.92      0.87       723
#            2       0.68      0.52      0.59       227
#
#     accuracy                           0.80       980
#    macro avg       0.70      0.51      0.54       980
# weighted avg       0.79      0.80      0.79       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7748814085020983
# Accuracy (test):0.7806122448979592
# [[  7  23   0]
#  [  6 650  67]
#  [  0 119 108]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.23      0.33        30
#            1       0.82      0.90      0.86       723
#            2       0.62      0.48      0.54       227
#
#     accuracy                           0.78       980
#    macro avg       0.66      0.54      0.57       980
# weighted avg       0.76      0.78      0.77       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7789643443584331
# Accuracy (test):0.7846938775510204
# [[  0  30   0]
#  [  2 683  38]
#  [  0 141  86]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.80      0.94      0.87       723
#            2       0.69      0.38      0.49       227
#
#     accuracy                           0.78       980
#    macro avg       0.50      0.44      0.45       980
# weighted avg       0.75      0.78      0.75       980

# %%
# Drop 4 columns with least variance

# Define columns with Least variance
col_drop = ['chlorides', 'volatile acidity', 'citric acid', 'sulphates']

# Use 7 features with the highest variances
# - Drop columns with least variances from x_train and x_test
x_train.drop(col_drop, axis = 1, inplace = True)
x_test.drop(col_drop, axis = 1, inplace = True)

# %%
#Case 2: 7 features

performance(estimators, x_train, x_test, y_train, y_test)
# Out:
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.7993855396564756
# Accuracy (test):0.8020408163265306
# [[  3  26   1]
#  [  2 668  53]
#  [  0 112 115]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.10      0.17        30
#            1       0.83      0.92      0.87       723
#            2       0.68      0.51      0.58       227
#
#     accuracy                           0.80       980
#    macro avg       0.70      0.51      0.54       980
# weighted avg       0.79      0.80      0.78       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7595648604269293
# Accuracy (test):0.7775510204081633
# [[  1  29   0]
#  [  4 671  48]
#  [  2 135  90]]
#               precision    recall  f1-score   support
#
#            0       0.14      0.03      0.05        30
#            1       0.80      0.93      0.86       723
#            2       0.65      0.40      0.49       227
#
#     accuracy                           0.78       980
#    macro avg       0.53      0.45      0.47       980
# weighted avg       0.75      0.78      0.75       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7863675163552011
# Accuracy (test):0.8
# [[  0  30   0]
#  [  0 698  25]
#  [  0 141  86]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.80      0.97      0.88       723
#            2       0.77      0.38      0.51       227
#
#     accuracy                           0.80       980
#    macro avg       0.53      0.45      0.46       980
# weighted avg       0.77      0.80      0.76       980
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Drop another 4 columns with least variance

# Define columns with Least variance
col_drop = ['density', 'pH', 'fixed acidity', 'total sulfur dioxide']

# Use 3 features with the highest variances
# - Drop columns with least variances from x_train and x_test
x_train.drop(col_drop, axis = 1, inplace = True)
x_test.drop(col_drop, axis = 1, inplace = True)

x_train.head(1)
# Out:
#       residual sugar  free sulfur dioxide  alcohol
# 4665             8.2                 44.0     12.4

# %%
#Case 3: 3 features

performance(estimators, x_train, x_test, y_train, y_test)
# Out:
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.8011732087471003
# Accuracy (test):0.8153061224489796
# [[  5  25   0]
#  [  2 675  46]
#  [  0 108 119]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.17      0.27        30
#            1       0.84      0.93      0.88       723
#            2       0.72      0.52      0.61       227
#
#     accuracy                           0.82       980
#    macro avg       0.76      0.54      0.59       980
# weighted avg       0.81      0.82      0.80       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7618666432090079
# Accuracy (test):0.7663265306122449
# [[  2  28   0]
#  [  2 688  33]
#  [  0 166  61]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.07      0.12        30
#            1       0.78      0.95      0.86       723
#            2       0.65      0.27      0.38       227
#
#     accuracy                           0.77       980
#    macro avg       0.64      0.43      0.45       980
# weighted avg       0.74      0.77      0.72       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7702889201657674
# Accuracy (test):0.7744897959183673
# [[  1  29   0]
#  [  0 694  29]
#  [  0 163  64]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.03      0.06        30
#            1       0.78      0.96      0.86       723
#            2       0.69      0.28      0.40       227
#
#     accuracy                           0.77       980
#    macro avg       0.82      0.43      0.44       980
# weighted avg       0.77      0.77      0.73       980

# %%
# Filter approach using chi-square

# Create new copy of df
df_chi = df.copy()
df_chi.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
#
#    alcohol quality
# 0      8.8       1

# %%
# Indicate the target column
target = df_chi['quality']

# Indicate the columns that will serve as features
features = df_chi.drop('quality', axis = 1)

features.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  alcohol
# 0                 45.0                 170.0    1.001  3.0       0.45      8.8

# %%
# Split the dataset into training and test sets
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

# %%
#Scaling Data
normalize_scaler(df_chi)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.060535          0.001410     0.002985        0.067998   0.000232
# 1          0.031264          0.001241     0.002184        0.057566   0.000203
# 2          0.056364          0.003221     0.003321        0.074481   0.000372
# 3          0.064430          0.001774     0.003268        0.015874   0.000336
# 4          0.042970          0.001674     0.001451        0.105752   0.000296
# ...             ...               ...          ...             ...        ...
# 3913       0.048857          0.001655     0.004098        0.051221   0.000370
# 3914       0.046130          0.000923     0.002109        0.059309   0.000257
# 3915       0.048959          0.001739     0.003350        0.020614   0.000277
# 3916       0.043354          0.001652     0.001996        0.094279   0.000241
# 3917       0.073209          0.002440     0.003163        0.015365   0.000271
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                0.364866              0.920458  0.008232  0.026038
# 1                0.238205              0.967708  0.004947  0.015781
# 2                0.251624              0.956171  0.009991  0.032711
# 3                0.308144              0.943107  0.009274  0.029974
# 4                0.200900              0.971019  0.005579  0.017858
# ...                   ...                   ...       ...       ...
# 3913             0.220646              0.969267  0.007834  0.025374
# 3914             0.355856              0.929181  0.006561  0.021220
# 3915             0.180376              0.979185  0.006386  0.019455
# 3916             0.364728              0.922143  0.006852  0.021815
# 3917             0.343451              0.930932  0.008971  0.029103
#
#       sulphates   alcohol
# 0      0.003400  0.102826
# 1      0.002581  0.047145
# 2      0.004932  0.111721
# 3      0.005042  0.100847
# 4      0.002790  0.058038
# ...         ...       ...
# 3913   0.003861  0.078014
# 3914   0.002834  0.061945
# 3915   0.003414  0.073439
# 3916   0.002615  0.072946
# 3917   0.005694  0.093997
#
# [3918 rows x 11 columns]

# %%
# Create a selector
# Setting k = 7 means we want the top 7 features 
selector = SelectKBest(chi2, k = 7)

# Select top 7 features based on the training set
x_new = selector.fit_transform(x_train, y_train) 
selector.get_support(indices=True)
# Out:
# array([ 0,  1,  3,  4,  5,  6, 10])

# %%
# Drop 4 columns: array([ 2, 7, 8, 9])
col_drop = ['citric acid', 'density', 'pH', 'sulphates']

# Use 7 features with the top 7 features 
x_train.drop(col_drop, axis = 1, inplace = True)
x_test.drop(col_drop, axis = 1, inplace = True)

x_train.head(1)
# Out:
#       fixed acidity  volatile acidity  residual sugar  chlorides  \
# 4665            7.3              0.17             8.2      0.028
#
#       free sulfur dioxide  total sulfur dioxide  alcohol
# 4665                 44.0                 111.0     12.4

# %%
#Case 1: 7 features

performance(estimators, x_train, x_test, y_train, y_test)
# Out:
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.7996409674981104
# Accuracy (test):0.7979591836734694
# [[  3  26   1]
#  [  2 666  55]
#  [  0 114 113]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.10      0.17        30
#            1       0.83      0.92      0.87       723
#            2       0.67      0.50      0.57       227
#
#     accuracy                           0.80       980
#    macro avg       0.70      0.51      0.54       980
# weighted avg       0.78      0.80      0.78       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7605904814032893
# Accuracy (test):0.7683673469387755
# [[  3  27   0]
#  [  8 665  50]
#  [  0 142  85]]
#               precision    recall  f1-score   support
#
#            0       0.27      0.10      0.15        30
#            1       0.80      0.92      0.85       723
#            2       0.63      0.37      0.47       227
#
#     accuracy                           0.77       980
#    macro avg       0.57      0.46      0.49       980
# weighted avg       0.74      0.77      0.74       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.786622292595199
# Accuracy (test):0.8
# [[  0  30   0]
#  [  0 698  25]
#  [  0 141  86]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.80      0.97      0.88       723
#            2       0.77      0.38      0.51       227
#
#     accuracy                           0.80       980
#    macro avg       0.53      0.45      0.46       980
# weighted avg       0.77      0.80      0.76       980
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Create a selector
# Setting k = 3 means we want the top 3 features 
selector = SelectKBest(chi2, k = 3)

# Select top 3 features based on the training set
x_new = selector.fit_transform(x_train, y_train) 
selector.get_support(indices = True)
# Out:
# array([2, 4, 5])

# %%
# Drop another 4 columns: array([0, 1, 3, 6])
col_drop = ['fixed acidity', 'volatile acidity', 'chlorides', 'alcohol']

# Use 3 features with the top 3 features 
x_train.drop(col_drop, axis = 1, inplace = True)
x_test.drop(col_drop, axis = 1, inplace = True)

x_train.head(1)
# Out:
#       residual sugar  free sulfur dioxide  total sulfur dioxide
# 4665             8.2                 44.0                 111.0

# %%
#Case 2: 3 features

performance(estimators, x_train, x_test, y_train, y_test)
# Out:
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.7866258764042016
# Accuracy (test):0.7908163265306123
# [[  2  26   2]
#  [  2 666  55]
#  [  0 120 107]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.07      0.12        30
#            1       0.82      0.92      0.87       723
#            2       0.65      0.47      0.55       227
#
#     accuracy                           0.79       980
#    macro avg       0.66      0.49      0.51       980
# weighted avg       0.77      0.79      0.77       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7409375244350614
# Accuracy (test):0.7479591836734694
# [[  5  25   0]
#  [  1 718   4]
#  [  2 215  10]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.17      0.26        30
#            1       0.75      0.99      0.85       723
#            2       0.71      0.04      0.08       227
#
#     accuracy                           0.75       980
#    macro avg       0.70      0.40      0.40       980
# weighted avg       0.74      0.75      0.66       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7835646519144056
# Accuracy (test):0.7959183673469388
# [[  1  28   1]
#  [  0 702  21]
#  [  0 150  77]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.03      0.06        30
#            1       0.80      0.97      0.88       723
#            2       0.78      0.34      0.47       227
#
#     accuracy                           0.80       980
#    macro avg       0.86      0.45      0.47       980
# weighted avg       0.80      0.80      0.76       980

# %%
# Filter approach using Information Gain

# Create new copy of df
df_inf = df.copy()

df_inf.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
#
#    alcohol quality
# 0      8.8       1

# %%
# Indicate the target column
target = df_inf['quality']

# Indicate the columns that will serve as features
features = df_inf.drop('quality', axis = 1)

features.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  alcohol
# 0                 45.0                 170.0    1.001  3.0       0.45      8.8

# %%
# Split the dataset into training and test sets
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

# %%
#Scaling Data
normalize_scaler(df_inf)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.060535          0.001410     0.002985        0.067998   0.000232
# 1          0.031264          0.001241     0.002184        0.057566   0.000203
# 2          0.056364          0.003221     0.003321        0.074481   0.000372
# 3          0.064430          0.001774     0.003268        0.015874   0.000336
# 4          0.042970          0.001674     0.001451        0.105752   0.000296
# ...             ...               ...          ...             ...        ...
# 3913       0.048857          0.001655     0.004098        0.051221   0.000370
# 3914       0.046130          0.000923     0.002109        0.059309   0.000257
# 3915       0.048959          0.001739     0.003350        0.020614   0.000277
# 3916       0.043354          0.001652     0.001996        0.094279   0.000241
# 3917       0.073209          0.002440     0.003163        0.015365   0.000271
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                0.364866              0.920458  0.008232  0.026038
# 1                0.238205              0.967708  0.004947  0.015781
# 2                0.251624              0.956171  0.009991  0.032711
# 3                0.308144              0.943107  0.009274  0.029974
# 4                0.200900              0.971019  0.005579  0.017858
# ...                   ...                   ...       ...       ...
# 3913             0.220646              0.969267  0.007834  0.025374
# 3914             0.355856              0.929181  0.006561  0.021220
# 3915             0.180376              0.979185  0.006386  0.019455
# 3916             0.364728              0.922143  0.006852  0.021815
# 3917             0.343451              0.930932  0.008971  0.029103
#
#       sulphates   alcohol
# 0      0.003400  0.102826
# 1      0.002581  0.047145
# 2      0.004932  0.111721
# 3      0.005042  0.100847
# 4      0.002790  0.058038
# ...         ...       ...
# 3913   0.003861  0.078014
# 3914   0.002834  0.061945
# 3915   0.003414  0.073439
# 3916   0.002615  0.072946
# 3917   0.005694  0.093997
#
# [3918 rows x 11 columns]

# %%
# Create a selector
# Setting k = 7 means we want the top 7 features 
selector = SelectKBest(mutual_info_classif, k = 7)

# Select top 7 features based on the training set
x_new = selector.fit_transform(x_train, y_train) 
selector.get_support(indices = True)
# Out:
# array([ 2,  3,  4,  5,  6,  7, 10])

# %%
# Drop 4 bottom columns: array([ 0, 2, 8, 9])
col_drop = ['fixed acidity', 'citric acid', 'pH', 'sulphates']

# Use 7 features with the top 7 features 
x_train.drop(col_drop, axis = 1, inplace = True)
x_test.drop(col_drop, axis = 1, inplace = True)

x_train.head(1)
# Out:
#       volatile acidity  residual sugar  chlorides  free sulfur dioxide  \
# 4665              0.17             8.2      0.028                 44.0
#
#       total sulfur dioxide  density  alcohol
# 4665                 111.0  0.99272     12.4

# %%
#Case 1: 7 features

performance(estimators, x_train, x_test, y_train, y_test)
# Out:
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.8004088800271066
# Accuracy (test):0.7989795918367347
# [[  2  26   2]
#  [  2 668  53]
#  [  0 114 113]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.07      0.12        30
#            1       0.83      0.92      0.87       723
#            2       0.67      0.50      0.57       227
#
#     accuracy                           0.80       980
#    macro avg       0.67      0.50      0.52       980
# weighted avg       0.78      0.80      0.78       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7567603669820419
# Accuracy (test):0.7816326530612245
# [[  5  25   0]
#  [  8 675  40]
#  [  0 141  86]]
#               precision    recall  f1-score   support
#
#            0       0.38      0.17      0.23        30
#            1       0.80      0.93      0.86       723
#            2       0.68      0.38      0.49       227
#
#     accuracy                           0.78       980
#    macro avg       0.62      0.49      0.53       980
# weighted avg       0.76      0.78      0.76       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7825396825396825
# Accuracy (test):0.7918367346938775
# [[  0  30   0]
#  [  2 691  30]
#  [  0 142  85]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.80      0.96      0.87       723
#            2       0.74      0.37      0.50       227
#
#     accuracy                           0.79       980
#    macro avg       0.51      0.44      0.46       980
# weighted avg       0.76      0.79      0.76       980

# %%
# Create a selector
# Setting k = 3 means we want the top 3 features 
selector = SelectKBest(chi2, k = 3)

# Select top 3 features based on the training set
x_new = selector.fit_transform(x_train, y_train) 
selector.get_support(indices = True)
# Out:
# array([1, 3, 4])

# %%
# Drop another 4 bottom columns: array([0, 2, 5, 6])
col_drop = ['volatile acidity', 'chlorides', 'density', 'alcohol']

# Use 3 features with the top 3 features 
x_train.drop(col_drop, axis = 1, inplace = True)
x_test.drop(col_drop, axis = 1, inplace = True)

x_train.head()
# Out:
#       residual sugar  free sulfur dioxide  total sulfur dioxide
# 4665            8.20                 44.0                 111.0
# 1943           11.60                 48.0                 195.0
# 3399            7.40                 25.0                  95.0
# 843             1.70                 33.0                 101.0
# 2580           18.95                 36.0                 174.0

# %%
#Case 2: 3 features

performance(estimators, x_train, x_test, y_train, y_test)
# Out:
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.7866258764042016
# Accuracy (test):0.7908163265306123
# [[  2  26   2]
#  [  2 666  55]
#  [  0 120 107]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.07      0.12        30
#            1       0.82      0.92      0.87       723
#            2       0.65      0.47      0.55       227
#
#     accuracy                           0.79       980
#    macro avg       0.66      0.49      0.51       980
# weighted avg       0.77      0.79      0.77       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7409375244350614
# Accuracy (test):0.7459183673469387
# [[  4  26   0]
#  [  2 717   4]
#  [  2 215  10]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.13      0.21        30
#            1       0.75      0.99      0.85       723
#            2       0.71      0.04      0.08       227
#
#     accuracy                           0.75       980
#    macro avg       0.65      0.39      0.38       980
# weighted avg       0.73      0.75      0.66       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7835646519144056
# Accuracy (test):0.7959183673469388
# [[  1  28   1]
#  [  0 702  21]
#  [  0 150  77]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.03      0.06        30
#            1       0.80      0.97      0.88       723
#            2       0.78      0.34      0.47       227
#
#     accuracy                           0.80       980
#    macro avg       0.86      0.45      0.47       980
# weighted avg       0.80      0.80      0.76       980

# %%
# Wapper approach using Recursive Feature Elimination

# Create new copy of df
df_rfe = df.copy()

df_rfe.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
#
#    alcohol quality
# 0      8.8       1

# %%
# Indicate the target column
target = df_rfe['quality']

# Indicate the columns that will serve as features
features = df_rfe.drop('quality', axis = 1)

features.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  alcohol
# 0                 45.0                 170.0    1.001  3.0       0.45      8.8

# %%
# Split the dataset into training and test sets
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

# %%
#Scaling Data
normalize_scaler(df_rfe)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.060535          0.001410     0.002985        0.067998   0.000232
# 1          0.031264          0.001241     0.002184        0.057566   0.000203
# 2          0.056364          0.003221     0.003321        0.074481   0.000372
# 3          0.064430          0.001774     0.003268        0.015874   0.000336
# 4          0.042970          0.001674     0.001451        0.105752   0.000296
# ...             ...               ...          ...             ...        ...
# 3913       0.048857          0.001655     0.004098        0.051221   0.000370
# 3914       0.046130          0.000923     0.002109        0.059309   0.000257
# 3915       0.048959          0.001739     0.003350        0.020614   0.000277
# 3916       0.043354          0.001652     0.001996        0.094279   0.000241
# 3917       0.073209          0.002440     0.003163        0.015365   0.000271
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                0.364866              0.920458  0.008232  0.026038
# 1                0.238205              0.967708  0.004947  0.015781
# 2                0.251624              0.956171  0.009991  0.032711
# 3                0.308144              0.943107  0.009274  0.029974
# 4                0.200900              0.971019  0.005579  0.017858
# ...                   ...                   ...       ...       ...
# 3913             0.220646              0.969267  0.007834  0.025374
# 3914             0.355856              0.929181  0.006561  0.021220
# 3915             0.180376              0.979185  0.006386  0.019455
# 3916             0.364728              0.922143  0.006852  0.021815
# 3917             0.343451              0.930932  0.008971  0.029103
#
#       sulphates   alcohol
# 0      0.003400  0.102826
# 1      0.002581  0.047145
# 2      0.004932  0.111721
# 3      0.005042  0.100847
# 4      0.002790  0.058038
# ...         ...       ...
# 3913   0.003861  0.078014
# 3914   0.002834  0.061945
# 3915   0.003414  0.073439
# 3916   0.002615  0.072946
# 3917   0.005694  0.093997
#
# [3918 rows x 11 columns]

# %%
# Create a SVM classifier with linear kernel
svmlinear = SVC(kernel = 'linear')

# Use RFE to rank features and return top 7 features
# Parameter step corresponds to the (integer) number of features to remove at each iteratio 
rfe = RFE(estimator = svmlinear, n_features_to_select = 7, step = 1)
rfe.fit(x_train, y_train)

print("Number of Features: ", rfe.n_features_)
print("Feature Ranking: ", rfe.ranking_)
print("Selected Features: ", rfe.support_)
# Out:
# Number of Features:  7
# Feature Ranking:  [1 1 1 2 1 4 5 3 1 1 1]
# Selected Features:  [ True  True  True False  True False False False  True  True  True]

# %%
# Drop 4 bottom columns: array([ 3, 5, 6, 7])
col_drop = ['residual sugar', 'free sulfur dioxide', 'total sulfur dioxide', 'density']

# Use 7 features with the top 7 features 
x_train.drop(col_drop, axis = 1, inplace = True)
x_test.drop(col_drop, axis = 1, inplace = True)

x_train.head(1)
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides    pH  \
# 4665            7.3              0.17         0.36      0.028  3.14
#
#       sulphates  alcohol
# 4665       0.41     12.4

# %%
#Case 1: 7 features

performance(estimators, x_train, x_test, y_train, y_test)
# Out:
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.8134216905152865
# Accuracy (test):0.8408163265306122
# [[  3  27   0]
#  [  1 667  55]
#  [  0  73 154]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.10      0.18        30
#            1       0.87      0.92      0.90       723
#            2       0.74      0.68      0.71       227
#
#     accuracy                           0.84       980
#    macro avg       0.79      0.57      0.59       980
# weighted avg       0.84      0.84      0.83       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7656967576302551
# Accuracy (test):0.7816326530612245
# [[  5  24   1]
#  [ 10 666  47]
#  [  0 132  95]]
#               precision    recall  f1-score   support
#
#            0       0.33      0.17      0.22        30
#            1       0.81      0.92      0.86       723
#            2       0.66      0.42      0.51       227
#
#     accuracy                           0.78       980
#    macro avg       0.60      0.50      0.53       980
# weighted avg       0.76      0.78      0.76       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7695258946490474
# Accuracy (test):0.7591836734693878
# [[  0  30   0]
#  [  0 696  27]
#  [  0 179  48]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.77      0.96      0.86       723
#            2       0.64      0.21      0.32       227
#
#     accuracy                           0.76       980
#    macro avg       0.47      0.39      0.39       980
# weighted avg       0.72      0.76      0.70       980
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Use RFE to rank features and return top 3 features
# Parameter step corresponds to the (integer) number of features to remove at each iteratio 
rfe = RFE(estimator = svmlinear, n_features_to_select = 3, step = 1)
rfe.fit(x_train, y_train)

print("Number of Features: ", rfe.n_features_)
print("Feature Ranking: ", rfe.ranking_)
print("Selected Features: ", rfe.support_)
# Out:
# Number of Features:  3
# Feature Ranking:  [5 1 4 1 3 1 2]
# Selected Features:  [False  True False  True False  True False]

# %%
# Drop another 4 bottom columns: array([ 0, 2, 4, 6])

col_drop = ['fixed acidity', 'citric acid', 'pH', 'alcohol']

# Use 7 features with the top 3 features 
x_train.drop(col_drop, axis = 1, inplace = True)
x_test.drop(col_drop, axis = 1, inplace = True)

x_train.head(1)
# Out:
#       volatile acidity  chlorides  sulphates
# 4665              0.17      0.028       0.41

# %%
#Case 2: 3 features

performance(estimators, x_train, x_test, y_train, y_test)
# Out:
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.7861137175176585
# Accuracy (test):0.786734693877551
# [[  2  26   2]
#  [  6 656  61]
#  [  1 113 113]]
#               precision    recall  f1-score   support
#
#            0       0.22      0.07      0.10        30
#            1       0.83      0.91      0.86       723
#            2       0.64      0.50      0.56       227
#
#     accuracy                           0.79       980
#    macro avg       0.56      0.49      0.51       980
# weighted avg       0.76      0.79      0.77       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7340491177313837
# Accuracy (test):0.736734693877551
# [[  3  27   0]
#  [  5 676  42]
#  [  3 181  43]]
#               precision    recall  f1-score   support
#
#            0       0.27      0.10      0.15        30
#            1       0.76      0.93      0.84       723
#            2       0.51      0.19      0.28       227
#
#     accuracy                           0.74       980
#    macro avg       0.51      0.41      0.42       980
# weighted avg       0.69      0.74      0.69       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7483410222326479
# Accuracy (test):0.7377551020408163
# [[  0  30   0]
#  [  0 723   0]
#  [  0 227   0]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.74      1.00      0.85       723
#            2       0.00      0.00      0.00       227
#
#     accuracy                           0.74       980
#    macro avg       0.25      0.33      0.28       980
# weighted avg       0.54      0.74      0.63       980
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Principal Component Analysis

# Create new copy of df
df_pca = df.copy()

df_pca.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
#
#    alcohol quality
# 0      8.8       1

# %%
# Indicate the target column
target = df_pca['quality']

# Indicate the columns that will serve as features
features = df_pca.drop('quality', axis = 1)

features.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  alcohol
# 0                 45.0                 170.0    1.001  3.0       0.45      8.8

# %%
# Split the dataset into training and test sets
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

# %%
#Scaling Data
normalize_scaler(df_pca)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.060535          0.001410     0.002985        0.067998   0.000232
# 1          0.031264          0.001241     0.002184        0.057566   0.000203
# 2          0.056364          0.003221     0.003321        0.074481   0.000372
# 3          0.064430          0.001774     0.003268        0.015874   0.000336
# 4          0.042970          0.001674     0.001451        0.105752   0.000296
# ...             ...               ...          ...             ...        ...
# 3913       0.048857          0.001655     0.004098        0.051221   0.000370
# 3914       0.046130          0.000923     0.002109        0.059309   0.000257
# 3915       0.048959          0.001739     0.003350        0.020614   0.000277
# 3916       0.043354          0.001652     0.001996        0.094279   0.000241
# 3917       0.073209          0.002440     0.003163        0.015365   0.000271
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                0.364866              0.920458  0.008232  0.026038
# 1                0.238205              0.967708  0.004947  0.015781
# 2                0.251624              0.956171  0.009991  0.032711
# 3                0.308144              0.943107  0.009274  0.029974
# 4                0.200900              0.971019  0.005579  0.017858
# ...                   ...                   ...       ...       ...
# 3913             0.220646              0.969267  0.007834  0.025374
# 3914             0.355856              0.929181  0.006561  0.021220
# 3915             0.180376              0.979185  0.006386  0.019455
# 3916             0.364728              0.922143  0.006852  0.021815
# 3917             0.343451              0.930932  0.008971  0.029103
#
#       sulphates   alcohol
# 0      0.003400  0.102826
# 1      0.002581  0.047145
# 2      0.004932  0.111721
# 3      0.005042  0.100847
# 4      0.002790  0.058038
# ...         ...       ...
# 3913   0.003861  0.078014
# 3914   0.002834  0.061945
# 3915   0.003414  0.073439
# 3916   0.002615  0.072946
# 3917   0.005694  0.093997
#
# [3918 rows x 11 columns]

# %%
# Specify the number of components = 7
pca = PCA(n_components = 7)

# Generate the principal components
pca.fit(x_train)

# Transform the training set into principal components
train_pca = pca.transform(x_train)

# Transform the test set into principal components
test_pca = pca.transform(x_test)

# Convert train set into a data frame to make it easier to view
col_pca = ['principal component 1', 'principal component 2', 'principal component 3', 'principal component 4',\
          'principal component 5', 'principal component 6', 'principal component 7']

principalDf = pd.DataFrame(data = train_pca, columns = col_pca)

principalDf.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0             -23.679791              15.651154               2.504163
# 1              58.585940              -2.252917               2.322404
# 2             -44.054223               1.456679               3.062976
# 3             -36.470910               7.503535              -3.072416
# 4              35.575768              -8.255546              10.858227
#
#    principal component 4  principal component 5  principal component 6  \
# 0               1.598024               0.828449              -0.007527
# 1               0.045068              -0.695104              -0.038144
# 2               0.448083              -1.170754              -0.015628
# 3              -0.495367               0.122794               0.042162
# 4               1.184435               0.748087               0.127777
#
#    principal component 7
# 0               0.008663
# 1               0.125526
# 2               0.047601
# 3               0.061736
# 4              -0.107691

# %%
for num in range(1, principalDf.shape[1]+1):
    print("Number of principal components: {}".format(num))
    print("**********************************************")
    
    df_pca_train = pd.DataFrame(data = train_pca[:,:num], columns = col_pca[:num])
    df_pca_test = pd.DataFrame(data = test_pca[:,:num], columns = col_pca[:num])
  
    performance(estimators, df_pca_train, df_pca_test, y_train, y_test)
# Out:
# Number of principal components: 1
# **********************************************
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.7628912867829124
# Accuracy (test):0.7765306122448979
# [[  2  26   2]
#  [  9 656  58]
#  [  2 122 103]]
#               precision    recall  f1-score   support
#
#            0       0.15      0.07      0.09        30
#            1       0.82      0.91      0.86       723
#            2       0.63      0.45      0.53       227
#
#     accuracy                           0.78       980
#    macro avg       0.53      0.48      0.49       980
# weighted avg       0.75      0.78      0.76       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7409368728334245
# Accuracy (test):0.7408163265306122
# [[  0  30   0]
#  [  5 717   1]
#  [  2 216   9]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.74      0.99      0.85       723
#            2       0.90      0.04      0.08       227
#
#     accuracy                           0.74       980
#    macro avg       0.55      0.34      0.31       980
# weighted avg       0.76      0.74      0.65       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7445096046081268
# Accuracy (test):0.7387755102040816
# [[  0  30   0]
#  [  0 722   1]
#  [  0 225   2]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.74      1.00      0.85       723
#            2       0.67      0.01      0.02       227
#
#     accuracy                           0.74       980
#    macro avg       0.47      0.34      0.29       980
# weighted avg       0.70      0.74      0.63       980
#
#
# Number of principal components: 2
# **********************************************
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.7792253108139808
# Accuracy (test):0.7775510204081633
# [[  4  23   3]
#  [  5 643  75]
#  [  0 112 115]]
#               precision    recall  f1-score   support
#
#            0       0.44      0.13      0.21        30
#            1       0.83      0.89      0.86       723
#            2       0.60      0.51      0.55       227
#
#     accuracy                           0.78       980
#    macro avg       0.62      0.51      0.54       980
# weighted avg       0.76      0.78      0.77       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7401715667109755
# Accuracy (test):0.7255102040816327
# [[  2  26   2]
#  [  8 696  19]
#  [  1 213  13]]
#               precision    recall  f1-score   support
#
#            0       0.18      0.07      0.10        30
#            1       0.74      0.96      0.84       723
#            2       0.38      0.06      0.10       227
#
#     accuracy                           0.73       980
#    macro avg       0.44      0.36      0.35       980
# weighted avg       0.64      0.73      0.65       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy (validation)0.7636520316939036
# Accuracy (test):0.7428571428571429
# [[  0  28   2]
#  [  3 675  45]
#  [  0 174  53]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.77      0.93      0.84       723
#            2       0.53      0.23      0.32       227
#
#     accuracy                           0.74       980
#    macro avg       0.43      0.39      0.39       980
# weighted avg       0.69      0.74      0.70       980
#
#
# Number of principal components: 3
# **********************************************
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.780242460969062
# Accuracy (test):0.7887755102040817
# [[  4  24   2]
#  [  2 661  60]
#  [  0 119 108]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.13      0.22        30
#            1       0.82      0.91      0.87       723
#            2       0.64      0.48      0.54       227
#
#     accuracy                           0.79       980
#    macro avg       0.71      0.51      0.54       980
# weighted avg       0.77      0.79      0.77       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7462998801052988
# Accuracy (test):0.7438775510204082
# [[  5  24   1]
#  [  1 718   4]
#  [  1 220   6]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.17      0.27        30
#            1       0.75      0.99      0.85       723
#            2       0.55      0.03      0.05       227
#
#     accuracy                           0.74       980
#    macro avg       0.67      0.40      0.39       980
# weighted avg       0.70      0.74      0.65       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7830534704303177
# Accuracy (test):0.7938775510204081
# [[  1  28   1]
#  [  0 702  21]
#  [  0 152  75]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.03      0.06        30
#            1       0.80      0.97      0.87       723
#            2       0.77      0.33      0.46       227
#
#     accuracy                           0.79       980
#    macro avg       0.86      0.44      0.47       980
# weighted avg       0.80      0.79      0.75       980
#
#
# Number of principal components: 4
# **********************************************
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.798620559334845
# Accuracy (test):0.7989795918367347
# [[  3  26   1]
#  [  2 668  53]
#  [  0 115 112]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.10      0.17        30
#            1       0.83      0.92      0.87       723
#            2       0.67      0.49      0.57       227
#
#     accuracy                           0.80       980
#    macro avg       0.70      0.51      0.54       980
# weighted avg       0.78      0.80      0.78       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.760595042614747
# Accuracy (test):0.7673469387755102
# [[  2  28   0]
#  [ 10 674  39]
#  [  2 149  76]]
#               precision    recall  f1-score   support
#
#            0       0.14      0.07      0.09        30
#            1       0.79      0.93      0.86       723
#            2       0.66      0.33      0.44       227
#
#     accuracy                           0.77       980
#    macro avg       0.53      0.44      0.46       980
# weighted avg       0.74      0.77      0.74       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7945392524826023
# Accuracy (test):0.8081632653061225
# [[  1  29   0]
#  [  1 705  17]
#  [  0 141  86]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.03      0.06        30
#            1       0.81      0.98      0.88       723
#            2       0.83      0.38      0.52       227
#
#     accuracy                           0.81       980
#    macro avg       0.71      0.46      0.49       980
# weighted avg       0.80      0.81      0.77       980
#
#
# Number of principal components: 5
# **********************************************
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.7983661088956655
# Accuracy (test):0.8061224489795918
# [[  4  25   1]
#  [  2 670  51]
#  [  0 111 116]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.13      0.22        30
#            1       0.83      0.93      0.88       723
#            2       0.69      0.51      0.59       227
#
#     accuracy                           0.81       980
#    macro avg       0.73      0.52      0.56       980
# weighted avg       0.79      0.81      0.79       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7639113691453593
# Accuracy (test):0.7714285714285715
# [[  2  28   0]
#  [  5 665  53]
#  [  1 137  89]]
#               precision    recall  f1-score   support
#
#            0       0.25      0.07      0.11        30
#            1       0.80      0.92      0.86       723
#            2       0.63      0.39      0.48       227
#
#     accuracy                           0.77       980
#    macro avg       0.56      0.46      0.48       980
# weighted avg       0.74      0.77      0.75       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7955583574425938
# Accuracy (test):0.8122448979591836
# [[  1  29   0]
#  [  0 707  16]
#  [  0 139  88]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.03      0.06        30
#            1       0.81      0.98      0.88       723
#            2       0.85      0.39      0.53       227
#
#     accuracy                           0.81       980
#    macro avg       0.88      0.47      0.49       980
# weighted avg       0.82      0.81      0.78       980
#
#
# Number of principal components: 6
# **********************************************
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.7991307634164777
# Accuracy (test):0.8071428571428572
# [[  4  25   1]
#  [  2 669  52]
#  [  0 109 118]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.13      0.22        30
#            1       0.83      0.93      0.88       723
#            2       0.69      0.52      0.59       227
#
#     accuracy                           0.81       980
#    macro avg       0.73      0.53      0.56       980
# weighted avg       0.79      0.81      0.79       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7626342299371857
# Accuracy (test):0.7673469387755102
# [[  2  28   0]
#  [  2 693  28]
#  [  1 169  57]]
#               precision    recall  f1-score   support
#
#            0       0.40      0.07      0.11        30
#            1       0.78      0.96      0.86       723
#            2       0.67      0.25      0.37       227
#
#     accuracy                           0.77       980
#    macro avg       0.62      0.43      0.45       980
# weighted avg       0.74      0.77      0.72       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# Accuracy (validation)0.7907078348580812
# Accuracy (test):0.8
# [[  0  30   0]
#  [  0 701  22]
#  [  0 144  83]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.80      0.97      0.88       723
#            2       0.79      0.37      0.50       227
#
#     accuracy                           0.80       980
#    macro avg       0.53      0.45      0.46       980
# weighted avg       0.77      0.80      0.76       980
#
#
# Number of principal components: 7
# **********************************************
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Accuracy (validation)0.8014296139911903
# Accuracy (test):0.8081632653061225
# [[  4  25   1]
#  [  2 670  51]
#  [  0 109 118]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.13      0.22        30
#            1       0.83      0.93      0.88       723
#            2       0.69      0.52      0.59       227
#
#     accuracy                           0.81       980
#    macro avg       0.73      0.53      0.56       980
# weighted avg       0.80      0.81      0.79       980
#
#
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Accuracy (validation)0.7654445877968046
# Accuracy (test):0.763265306122449
# [[  9  21   0]
#  [ 12 689  22]
#  [  0 177  50]]
#               precision    recall  f1-score   support
#
#            0       0.43      0.30      0.35        30
#            1       0.78      0.95      0.86       723
#            2       0.69      0.22      0.33       227
#
#     accuracy                           0.76       980
#    macro avg       0.63      0.49      0.51       980
# weighted avg       0.75      0.76      0.72       980
#
#
# <class 'sklearn.svm._classes.SVC'>
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy (validation)0.7871337998801053
# Accuracy (test):0.7979591836734694
# [[  0  30   0]
#  [  0 697  26]
#  [  0 142  85]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.80      0.96      0.88       723
#            2       0.77      0.37      0.50       227
#
#     accuracy                           0.80       980
#    macro avg       0.52      0.45      0.46       980
# weighted avg       0.77      0.80      0.76       980
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/maru/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
